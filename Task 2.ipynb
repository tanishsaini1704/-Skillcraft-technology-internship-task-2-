# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv("Downloads/test.csv")

# %%
data.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked  Unnamed: 11  \
# 0  34.5      0      0   330911   7.8292   NaN        Q          NaN
# 1  47.0      1      0   363272   7.0000   NaN        S          NaN
# 2  62.0      0      0   240276   9.6875   NaN        Q          NaN
# 3  27.0      0      0   315154   8.6625   NaN        S          NaN
# 4  22.0      1      1  3101298  12.2875   NaN        S          NaN
#
#    Unnamed: 12  Unnamed: 13  Unnamed: 14
# 0          NaN          NaN          NaN
# 1          NaN          NaN          NaN
# 2          NaN          NaN          NaN
# 3          NaN          NaN          NaN
# 4          NaN          NaN          NaN

# %%
data.tail()
# Out:
#      PassengerId  Pclass                          Name     Sex   Age  SibSp  \
# 413         1305       3            Spector, Mr. Woolf    male   NaN      0
# 414         1306       1  Oliva y Ocana, Dona. Fermina  female  39.0      0
# 415         1307       3  Saether, Mr. Simon Sivertsen    male  38.5      0
# 416         1308       3           Ware, Mr. Frederick    male   NaN      0
# 417         1309       3      Peter, Master. Michael J    male   NaN      1
#
#      Parch              Ticket      Fare Cabin Embarked  Unnamed: 11  \
# 413      0           A.5. 3236    8.0500   NaN        S          NaN
# 414      0            PC 17758  108.9000  C105        C          NaN
# 415      0  SOTON/O.Q. 3101262    7.2500   NaN        S          NaN
# 416      0              359309    8.0500   NaN        S          NaN
# 417      1                2668   22.3583   NaN        C          NaN
#
#      Unnamed: 12  Unnamed: 13  Unnamed: 14
# 413          NaN          NaN          NaN
# 414          NaN          NaN          NaN
# 415          NaN          NaN          NaN
# 416          NaN          NaN          NaN
# 417          NaN          NaN          NaN

# %%
data.describe()
# Out:
#        PassengerId      Pclass         Age       SibSp       Parch  \
# count   418.000000  418.000000  332.000000  418.000000  418.000000
# mean   1100.500000    2.265550   30.272590    0.447368    0.392344
# std     120.810458    0.841838   14.181209    0.896760    0.981429
# min     892.000000    1.000000    0.170000    0.000000    0.000000
# 25%     996.250000    1.000000   21.000000    0.000000    0.000000
# 50%    1100.500000    3.000000   27.000000    0.000000    0.000000
# 75%    1204.750000    3.000000   39.000000    1.000000    0.000000
# max    1309.000000    3.000000   76.000000    8.000000    9.000000
#
#              Fare  Unnamed: 11  Unnamed: 12  Unnamed: 13  Unnamed: 14
# count  417.000000          0.0          0.0          0.0          0.0
# mean    35.627188          NaN          NaN          NaN          NaN
# std     55.907576          NaN          NaN          NaN          NaN
# min      0.000000          NaN          NaN          NaN          NaN
# 25%      7.895800          NaN          NaN          NaN          NaN
# 50%     14.454200          NaN          NaN          NaN          NaN
# 75%     31.500000          NaN          NaN          NaN          NaN
# max    512.329200          NaN          NaN          NaN          NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Pclass       418 non-null    int64
#  2   Name         418 non-null    object
#  3   Sex          418 non-null    object
#  4   Age          332 non-null    float64
#  5   SibSp        418 non-null    int64
#  6   Parch        418 non-null    int64
#  7   Ticket       418 non-null    object
#  8   Fare         417 non-null    float64
#  9   Cabin        91 non-null     object
#  10  Embarked     418 non-null    object
#  11  Unnamed: 11  0 non-null      float64
#  12  Unnamed: 12  0 non-null      float64
#  13  Unnamed: 13  0 non-null      float64
#  14  Unnamed: 14  0 non-null      float64
# dtypes: float64(6), int64(4), object(5)
# memory usage: 49.1+ KB

# %%
data.isnull().sum()
# Out:
# PassengerId      0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# Unnamed: 11    418
# Unnamed: 12    418
# Unnamed: 13    418
# Unnamed: 14    418
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
plt.figure(figsize=(6,3))
sns.histplot(data["Age"],kde=True)
plt.title("Age Distributed")
plt.xlabel("Age")
plt.ylabel("Count")
plt.show()

# %%
plt.figure(figsize=(6,3))
sns.countplot(data=data,x="Sex",hue="Sex")
plt.title("Survival by Gender")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.legend(title="survived",loc="upper right")
plt.show()
# Out:
# C:\Users\acer\AppData\Local\Temp\ipykernel_14308\2808194629.py:6: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend(title="survived",loc="upper right")

# %%
plt.figure(figsize=(6,3))
sns.scatterplot(data=data,x="Age",y="Fare",hue="Age")
plt.title("Scatter plot of Age and Fare")
plt.xlabel("Age")
plt.ylabel("Fare")
plt.legend(title="survived")
plt.show()
